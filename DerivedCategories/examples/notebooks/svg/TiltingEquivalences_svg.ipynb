# %%
using TikzPictures

# %%
tp = TikzPicture(L"""
    \coordinate(r) at (2.5,0);
    \coordinate(d) at (0,-1.5);
    
    \node(O) at ($0*(r)+0*(d)$)  {$\boldsymbol{\mathcal{O}}$};
    \node(O1) at ($1*(r)+0*(d)$) {$\boldsymbol{\mathcal{O}(1)}$};
    \node(O2) at ($2*(r)+0*(d)$) {$\boldsymbol{\mathcal{O}(2)}$};
    
    \path [>=latex,->,very thick] (O) edge[out=30,in=150] node[fill=white]{$\boldsymbol{x_0}$} (O1);
    \path [>=latex,->,very thick] (O) edge[out=0,in=180] node[fill=white]{$\boldsymbol{x_1}$} (O1);
    \path [>=latex,->,very thick] (O) edge[out=-30,in=-150] node[fill=white]{$\boldsymbol{x_2}$} (O1);
    
    \path [>=latex,->,very thick] (O1) edge[out=30,in=150] node[fill=white]{$\boldsymbol{y_0}$} (O2);
    \path [>=latex,->,very thick] (O1) edge[out=0,in=180] node[fill=white]{$\boldsymbol{y_1}$} (O2);
    \path [>=latex,->,very thick] (O1) edge[out=-30,in=-150] node[fill=white]{$\boldsymbol{y_2}$} (O2);
    """
, options="scale=2", preamble="\\usepackage{amssymb,bm}\\usetikzlibrary{arrows,calc}")

#save(SVG("beilinson_quiver"),tp)
# Out:
# TikzPicture(L"\coordinate(r) at (2.5,0);
# \coordinate(d) at (0,-1.5);
#
# \node(O) at ($0*(r)+0*(d)$)  {$\boldsymbol{\mathcal{O}}$};
# \node(O1) at ($1*(r)+0*(d)$) {$\boldsymbol{\mathcal{O}(1)}$};
# \node(O2) at ($2*(r)+0*(d)$) {$\boldsymbol{\mathcal{O}(2)}$};
#
# \path [>=latex,->,very thick] (O) edge[out=30,in=150] node[fill=white]{$\boldsymbol{x_0}$} (O1);
# \path [>=latex,->,very thick] (O) edge[out=0,in=180] node[fill=white]{$\boldsymbol{x_1}$} (O1);
# \path [>=latex,->,very thick] (O) edge[out=-30,in=-150] node[fill=white]{$\boldsymbol{x_2}$} (O1);
#
# \path [>=latex,->,very thick] (O1) edge[out=30,in=150] node[fill=white]{$\boldsymbol{y_0}$} (O2);
# \path [>=latex,->,very thick] (O1) edge[out=0,in=180] node[fill=white]{$\boldsymbol{y_1}$} (O2);
# \path [>=latex,->,very thick] (O1) edge[out=-30,in=-150] node[fill=white]{$\boldsymbol{y_2}$} (O2);
# ", "scale=2", "\\usepackage{amssymb,bm}\\usetikzlibrary{arrows,calc}", "tikzpicture", "", "", true, true)

# %%
tp = TikzPicture(L"""
    \coordinate (r) at (2.236,0);
    \coordinate (d) at (0,1.5);
        
        \node (w0xm1) {$0$};
        \node (w0x0) at ($(w0xm1)+3/4*(r)$) {$\mathcal{O}(0)^3$};
        \node (w0x1) at ($(w0x0)+(r)$) {$\mathcal{O}(1)^3$};
        \node (w0x2) at ($(w0x1)+(r)$) {$\mathcal{O}(2)$};
        \node (w0x3) at ($(w0x2)+3/4*(r)$){$0$};
        \node (w0) at ($(w0xm1)-1/2*(r)$) {$\Omega^2(2) :=$};
    
        \path (w0xm1) edge[>=latex,->] (w0x0);
        \path (w0x0) edge[>=latex,->] node[above]{$\begin{pmatrix}
            {x_1} & -{x_0} & {0 }   \\
            {x_2} & {0   } & -{x_0} \\
            {0  } & {x_2 } & -{x_1} \\
        \end{pmatrix}$} node[below,pos=0.05,scale=0.5]{$0$} (w0x1);
        \path (w0x1) edge[>=latex,->] node[above]{$\begin{pmatrix}
            {y_0} \\ {y_1} \\ {y_2}
    \end{pmatrix}$} (w0x2);
        \path (w0x2) edge[>=latex,->] (w0x3);
    
        \node (w1xm1) at ($-1*(d)$) {$0$};
        \node (w1x0)  at ($(w1xm1)+3/4*(r)$) {$\mathcal{O}(0)^3$};
        \node (w1x1)  at ($(w1x0)+(r)$) {$\mathcal{O}(1)$};
        \node (w1x2)  at ($(w1x1)+(r)$) {$0$};
        \node (w1x3)  at ($(w1x2)+3/4*(r)$) {$\phantom{v_3}$};
        \node (w1)    at ($(w1xm1)-1/2*(r)$) {$\Omega^1(1) :=$};
        
        \path (w1xm1) edge[>=latex,->] (w1x0);
        \path (w1x0) edge[>=latex,->] node[above]{${\begin{pmatrix}
            {x_0} \\ {x_1} \\ {x_2}
            \end{pmatrix}}$} node[below,pos=0.05,scale=0.5]{$0$} (w1x1);
        \path (w1x1) edge[>=latex,->] (w1x2);
        
        \node (w1xm1) at ($-2*(d)$) {$0$};
        \node (w1x0) at ($(w1xm1)+3/4*(r)$) {$\mathcal{O}(0)$};
        \node (w1x1) at ($(w1x0)+(r)$) {$0$};
        \node (w1x2) at ($(w1x1)+(r)$) {$\phantom{0}$};
        \node (w1x3) at ($(w1x2)+3/4*(r)$) {$\phantom{v_3}$};
        \node (w1) at ($(w1xm1)-1/2*(r)$) {$\Omega^0(0) :=$};
        
        \path (w1xm1) edge[>=latex,->] (w1x0);
        \path (w1x0) edge[>=latex,->] node[below,pos=0.05,scale=0.5]{$0$} (w1x1);
""", options="scale=2", preamble="\\usepackage{amsmath}\\usepackage{amssymb,bm}\\usetikzlibrary{arrows,calc}")

#save(SVG("omega_22_11_00"),tp)
# Out:
# TikzPicture(L"    \coordinate (r) at (2.236,0);
#     \coordinate (d) at (0,1.5);
#
#         \node (w0xm1) {$0$};
#         \node (w0x0) at ($(w0xm1)+3/4*(r)$) {$\mathcal{O}(0)^3$};
#         \node (w0x1) at ($(w0x0)+(r)$) {$\mathcal{O}(1)^3$};
#         \node (w0x2) at ($(w0x1)+(r)$) {$\mathcal{O}(2)$};
#         \node (w0x3) at ($(w0x2)+3/4*(r)$){$0$};
#         \node (w0) at ($(w0xm1)-1/2*(r)$) {$\Omega^2(2) :=$};
#
#         \path (w0xm1) edge[>=latex,->] (w0x0);
#         \path (w0x0) edge[>=latex,->] node[above]{$\begin{pmatrix}
#             {x_1} & -{x_0} & {0 }   \\
#             {x_2} & {0   } & -{x_0} \\
#             {0  } & {x_2 } & -{x_1} \\
#         \end{pmatrix}$} node[below,pos=0.05,scale=0.5]{$0$} (w0x1);
#         \path (w0x1) edge[>=latex,->] node[above]{$\begin{pmatrix}
#             {y_0} \\ {y_1} \\ {y_2}
#     \end{pmatrix}$} (w0x2);
#         \path (w0x2) edge[>=latex,->] (w0x3);
#
#         \node (w1xm1) at ($-1*(d)$) {$0$};
# ...

# %%
tp = TikzPicture(L"""
    \coordinate(r) at (2.5,0);
    \coordinate(d) at (0,-1.5);
    
    \node(O) at ($0*(r)+0*(d)$)  {$\boldsymbol{\Omega^2(2)}$};
    \node(O1) at ($1*(r)+0*(d)$) {$\boldsymbol{\Omega^1(1)}$};
    \node(O2) at ($2*(r)+0*(d)$) {$\boldsymbol{\Omega^0(0)}$};
    
    \path [>=latex,->,very thick] (O) edge[out=30,in=150] node[fill=white]{$\boldsymbol{m_{12}^1}$} (O1);
    \path [>=latex,->,very thick] (O) edge[out=0,in=180] node[fill=white]{$\boldsymbol{m_{12}^2}$} (O1);
    \path [>=latex,->,very thick] (O) edge[out=-30,in=-150] node[fill=white]{$\boldsymbol{m_{12}^3}$} (O1);
    
    \path [>=latex,->,very thick] (O1) edge[out=30,in=150] node[fill=white]{$\boldsymbol{m_{23}^1}$} (O2);
    \path [>=latex,->,very thick] (O1) edge[out=0,in=180] node[fill=white]{$\boldsymbol{m_{23}^2}$} (O2);
    \path [>=latex,->,very thick] (O1) edge[out=-30,in=-150] node[fill=white]{$\boldsymbol{m_{23}^3}$} (O2);
    """
, options="scale=2", preamble="\\usepackage{amssymb,bm}\\usetikzlibrary{arrows,calc}")

#save(SVG("abstraction-algebroid"),tp)
# Out:
# TikzPicture(L"\coordinate(r) at (2.5,0);
# \coordinate(d) at (0,-1.5);
#
# \node(O) at ($0*(r)+0*(d)$)  {$\boldsymbol{\Omega^2(2)}$};
# \node(O1) at ($1*(r)+0*(d)$) {$\boldsymbol{\Omega^1(1)}$};
# \node(O2) at ($2*(r)+0*(d)$) {$\boldsymbol{\Omega^0(0)}$};
#
# \path [>=latex,->,very thick] (O) edge[out=30,in=150] node[fill=white]{$\boldsymbol{m_{12}^1}$} (O1);
# \path [>=latex,->,very thick] (O) edge[out=0,in=180] node[fill=white]{$\boldsymbol{m_{12}^2}$} (O1);
# \path [>=latex,->,very thick] (O) edge[out=-30,in=-150] node[fill=white]{$\boldsymbol{m_{12}^3}$} (O1);
#
# \path [>=latex,->,very thick] (O1) edge[out=30,in=150] node[fill=white]{$\boldsymbol{m_{23}^1}$} (O2);
# \path [>=latex,->,very thick] (O1) edge[out=0,in=180] node[fill=white]{$\boldsymbol{m_{23}^2}$} (O2);
# \path [>=latex,->,very thick] (O1) edge[out=-30,in=-150] node[fill=white]{$\boldsymbol{m_{23}^3}$} (O2);
# ", "scale=2", "\\usepackage{amssymb,bm}\\usetikzlibrary{arrows,calc}", "tikzpicture", "", "", true, true)
